# %% [markdown]
# # OpenShift AI Inference Notebook
#
# Use this notebook to call a deployed OpenShift AI endpoint.

# %% [markdown]
# ## Set the endpoint
# Replace the URL with your OpenShift AI route.

# %%
endpoint = 'https://your-openshift-route.example.com/predict'

# %% [markdown]
# ## Send a request

# %%
import requests
payload = {
    'subject': 'Urgent: account verification',
    'body': 'Please verify your account to avoid suspension. Click the link.',
}
response = requests.post(endpoint, json=payload, timeout=60)
response.raise_for_status()
response.json()
